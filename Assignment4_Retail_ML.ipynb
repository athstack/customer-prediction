# %% [markdown]
# # Retail Customer & Transaction Dataset

# %% [markdown]
# GROUP NO:9
#
# Participants:
#
# 1. Adili S. Edward
# 2. Joseph M. Nzije
# 3. Carol F. Kika
# 4. Frank L. Mlyakalamu
# 5. Athanas J. Kayombo
# 6. Mathias B. Ngilangwa

# %% [markdown]
# # 1. Download all relevant CSV files.

# %% [markdown]
# # Import libraries

# %%
import os
from pathlib import Path
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %% [markdown]
# # Load ALL datasets

# %%
customers = pd.read_csv("data/customers.csv")
transactions = pd.read_csv("data/transactions.csv")
interactions = pd.read_csv("data/interactions.csv")
support_tickets = pd.read_csv("data/support_tickets.csv")
reviews = pd.read_csv("data/customer_reviews_complete.csv")
campaigns = pd.read_csv("data/campaigns.csv")

# %% [markdown]
# # QUESTION 2 — Inspect each dataset independently

# %% [markdown]
# Create a function:

# %%
def inspect_dataset(df, name):
    print("=" * 70)
    print(f"DATASET: {name}")
    print("=" * 70)

    print("Shape:", df.shape)

    print("\nColumns:")
    print(df.columns.tolist())

    print("\nData Types:")
    print(df.dtypes)

    print("\nMissing Values:")
    print(df.isnull().sum())

    print("\nDuplicate Rows:")
    print(df.duplicated().sum())

    print("\nFirst 5 Rows:")
    display(df.head())

    print("\nDescriptive Statistics:")
    display(df.describe(include="all"))

# %%
inspect_dataset(customers, "Customers")
inspect_dataset(transactions, "Transactions")
inspect_dataset(interactions, "Interactions")
inspect_dataset(support_tickets, "Support Tickets")
inspect_dataset(reviews, "Customer Reviews")
inspect_dataset(campaigns, "Campaigns")
# Out:
# ...
# DATASET: Customers
# ...
# Shape: (5000, 12)
#
# Columns:
# ['customer_id', 'full_name', 'age', 'gender', 'email', 'phone', 'street_address', 'city', 'state', 'zip_code', 'registration_date', 'preferred_channel']
#
# Data Types:
# customer_id              str
# full_name                str
# age                  float64
# gender                   str
# email                    str
# phone                    str
# street_address           str
# city                     str
# state                    str
# zip_code             float64
# registration_date        str
# preferred_channel        str
# dtype: object
#
# Missing Values:
# customer_id            0
# full_name            106
# age                  186
# gender               112
# email                111
# phone                186
# street_address       177
# city                  97
# state                 93
# zip_code              96
# registration_date      0
# preferred_channel    114
# dtype: int64
#
# Duplicate Rows:
# 0
#
# ...

# %% [markdown]
# # 3. Identify primary keys and foreign keys.

# %% [markdown]
#  Primary keys uniquely identify records within a table.
#  Foreign keys are columns that reference a primary key in
#  another table.
#
#  In this question we will:
#  1. Check candidate primary keys for uniqueness.
#  2. Check for missing primary-key values.
#  3. Identify foreign-key relationships.
#  4. Display the final PK/FK structure.

# %%
key_structure = pd.DataFrame({
    "Table": [
        "customers",
        "transactions",
        "interactions",
        "support_tickets",
        "customer_reviews_complete",
        "campaigns"
    ],

    "Primary Key": [
        "customer_id",
        "transaction_id",
        "interaction_id",
        "ticket_id",
        "review_id",
        "campaign_id"
    ],

    "Foreign Key": [
        "None",
        "customer_id",
        "customer_id",
        "customer_id",
        "customer_id",
        "None"
    ],

    "References": [
        "None",
        "customers.customer_id",
        "customers.customer_id",
        "customers.customer_id",
        "customers.customer_id",
        "None"
    ]
})

display(key_structure)
# Out:
#                        Table     Primary Key  Foreign Key  \
# 0                  customers     customer_id         None
# 1               transactions  transaction_id  customer_id
# 2               interactions  interaction_id  customer_id
# 3            support_tickets       ticket_id  customer_id
# 4  customer_reviews_complete       review_id  customer_id
# 5                  campaigns     campaign_id         None
#
#               References
# 0                   None
# 1  customers.customer_id
# 2  customers.customer_id
# 3  customers.customer_id
# 4  customers.customer_id
# 5                   None

# %% [markdown]
# # Verify the keys

# %%
# Verify primary-key uniqueness

primary_keys = {
    "customers": ("customer_id", customers),
    "transactions": ("transaction_id", transactions),
    "interactions": ("interaction_id", interactions),
    "support_tickets": ("ticket_id", support_tickets),
    "reviews": ("review_id", reviews),
    "campaigns": ("campaign_id", campaigns)
}

for table, (key, df) in primary_keys.items():

    print("=" * 70)
    print(table)

    print("Rows:", len(df))
    print("Unique keys:", df[key].nunique())
    print("Missing keys:", df[key].isna().sum())
    print("Duplicate keys:", df[key].duplicated().sum())
# Out:
# ...
# customers
# Rows: 5000
# Unique keys: 5000
# Missing keys: 0
# Duplicate keys: 0
# ...
# transactions
# Rows: 32295
# Unique keys: 32295
# Missing keys: 0
# Duplicate keys: 0
# ...
# interactions
# Rows: 100000
# Unique keys: 100000
# Missing keys: 0
# Duplicate keys: 0
# ...
# support_tickets
# Rows: 3000
# Unique keys: 3000
# Missing keys: 0
# Duplicate keys: 0
# ...
# reviews
# Rows: 1000
# Unique keys: 1000
# Missing keys: 0
# Duplicate keys: 0
# ...
# campaigns
# Rows: 200
# Unique keys: 200
# Missing keys: 0
# Duplicate keys: 0

# %% [markdown]
# Explaination:
#
# The primary and foreign keys of the datasets were identified by examining the uniqueness, missing values, and relationships between identifier columns.
#
# The `customers` table uses `customer_id` as its primary key. The `transactions`, `interactions`, `support_tickets`, and `customer_reviews_complete` tables contain `customer_id` as a foreign key referencing `customers.customer_id`.
#
# The `transactions` table uses `transaction_id` as its primary key, `interactions` uses `interaction_id`, `support_tickets` uses `ticket_id`, and `customer_reviews_complete` uses `review_id`.
#
# The `campaigns` table uses `campaign_id` as its primary key. It does not contain a direct `customer_id` foreign key, so it does not have a direct customer-level relationship with the other tables.
#
# Therefore, `customers.customer_id` serves as the central key for integrating the customer-related datasets.
#
# | Table                     | Primary Key    | Foreign Key |
# | ------------------------- | -------------- | ----------- |
# | customers                 | customer_id    | None        |
# | transactions              | transaction_id | customer_id |
# | interactions              | interaction_id | customer_id |
# | support_tickets           | ticket_id      | customer_id |
# | customer_reviews_complete | review_id      | customer_id |
# | campaigns                 | campaign_id    | None        |

# %% [markdown]
# # 4. Determine the relationships between tables.

# %%
relationships = pd.DataFrame({
    "Parent Table": [
        "customers",
        "customers",
        "customers",
        "customers"
    ],

    "Child Table": [
        "transactions",
        "interactions",
        "support_tickets",
        "customer_reviews_complete"
    ],

    "Parent Key": [
        "customer_id",
        "customer_id",
        "customer_id",
        "customer_id"
    ],

    "Child Key": [
        "customer_id",
        "customer_id",
        "customer_id",
        "customer_id"
    ],

    "Relationship": [
        "One-to-Many",
        "One-to-Many",
        "One-to-Many",
        "One-to-Many"
    ]
})

display(relationships)
# Out:
#   Parent Table                Child Table   Parent Key    Child Key  \
# 0    customers               transactions  customer_id  customer_id
# 1    customers               interactions  customer_id  customer_id
# 2    customers            support_tickets  customer_id  customer_id
# 3    customers  customer_reviews_complete  customer_id  customer_id
#
#   Relationship
# 0  One-to-Many
# 1  One-to-Many
# 2  One-to-Many
# 3  One-to-Many

# %% [markdown]
# # 5. Determine the correct merge/join strategy.

# %% [markdown]
# The customer table is used as the base dataset because the machine learning dataset is created at the customer level.
#
# A **LEFT JOIN** is used when merging the engineered features because all customers must be retained, including customers who may have no transactions, interactions, support tickets, or reviews.
#
# The engineered feature tables contain one row per `customer_id`, so the merges are performed using `customer_id` with a `one_to_one` validation strategy.

# %% [markdown]
# # 1. Create the customer-level base dataset

# %%
customers_ml = customers.copy()

print("CUSTOMER-LEVEL BASE DATASET")
print("-" * 50)
print("Rows:", len(customers_ml))
print("Unique customer IDs:", customers_ml["customer_id"].nunique())
print(
    "Duplicate customer IDs:",
    customers_ml["customer_id"].duplicated().sum()
)
# Out:
# CUSTOMER-LEVEL BASE DATASET
# --------------------------------------------------
# Rows: 5000
# Unique customer IDs: 5000
# Duplicate customer IDs: 0

# %% [markdown]
# # 2. Create customer-level transaction features

# %%
interaction_features = (
    interactions
    .groupby("customer_id")
    .agg(
        total_interactions=("interaction_id", "count")
    )
    .reset_index()
)

print("\nINTERACTION FEATURES")
print("-" * 50)
print("Rows:", len(interaction_features))
print(
    "Unique customer IDs:",
    interaction_features["customer_id"].nunique()
)
print(
    "Duplicate customer IDs:",
    interaction_features["customer_id"].duplicated().sum()
)
# Out:
# INTERACTION FEATURES
# --------------------------------------------------
# Rows: 4994
# Unique customer IDs: 4994
# Duplicate customer IDs: 0

# %% [markdown]
# # 3. Create customer-level interaction features

# %%
interaction_features = (
    interactions
    .groupby("customer_id")
    .agg(
        total_interactions=("interaction_id", "count")
    )
    .reset_index()
)

print("\nINTERACTION FEATURES")
print("-" * 50)
print("Rows:", len(interaction_features))
print(
    "Unique customer IDs:",
    interaction_features["customer_id"].nunique()
)
print(
    "Duplicate customer IDs:",
    interaction_features["customer_id"].duplicated().sum()
)
# Out:
# INTERACTION FEATURES
# --------------------------------------------------
# Rows: 4994
# Unique customer IDs: 4994
# Duplicate customer IDs: 0

# %% [markdown]
# # 4. Create customer-level support ticket features

# %%
ticket_features = (
    support_tickets
    .groupby("customer_id")
    .agg(
        total_tickets=("ticket_id", "count")
    )
    .reset_index()
)

print("\nSUPPORT TICKET FEATURES")
print("-" * 50)
print("Rows:", len(ticket_features))
print(
    "Unique customer IDs:",
    ticket_features["customer_id"].nunique()
)
print(
    "Duplicate customer IDs:",
    ticket_features["customer_id"].duplicated().sum()
)
# Out:
# SUPPORT TICKET FEATURES
# --------------------------------------------------
# Rows: 2196
# Unique customer IDs: 2196
# Duplicate customer IDs: 0

# %% [markdown]
# # 5. Create customer-level review features

# %%
review_features = (
    reviews
    .groupby("customer_id")
    .agg(
        total_reviews=("review_id", "count"),
        average_rating=("rating", "mean")
    )
    .reset_index()
)

print("\nREVIEW FEATURES")
print("-" * 50)
print("Rows:", len(review_features))
print(
    "Unique customer IDs:",
    review_features["customer_id"].nunique()
)
print(
    "Duplicate customer IDs:",
    review_features["customer_id"].duplicated().sum()
)
# Out:
# REVIEW FEATURES
# --------------------------------------------------
# Rows: 830
# Unique customer IDs: 830
# Duplicate customer IDs: 0

# %% [markdown]
# # 6. Determine the correct merge strategy

# %%
print("\n" + "=" * 60)
print("MERGE STRATEGY")
print("=" * 60)

print("""
A LEFT JOIN is used because customers_ml is the base
customer-level dataset.

All customers must remain in the final machine learning
dataset, even if a customer has no transactions,
interactions, support tickets, or reviews.

The feature tables contain one row per customer_id,
therefore one-to-one merge validation is appropriate.
""")
# Out:
# ...
# MERGE STRATEGY
# ...
#
# A LEFT JOIN is used because customers_ml is the base
# customer-level dataset.
#
# All customers must remain in the final machine learning
# dataset, even if a customer has no transactions,
# interactions, support tickets, or reviews.
#
# The feature tables contain one row per customer_id,
# therefore one-to-one merge validation is appropriate.

# %% [markdown]
# # 7. Start with the customer-level dataset

# %%
final_df = customers_ml.copy()

initial_rows = len(final_df)

print("Initial final_df rows:", initial_rows)
# Out:
# Initial final_df rows: 5000

# %% [markdown]
# # 8. Merge transaction features

# %%
before = len(final_df)

final_df = final_df.merge(
    transaction_features,
    on="customer_id",
    how="left",
    validate="one_to_one"
)

after = len(final_df)

print("\nCustomers + Transaction Features")
print("Before:", before)
print("After :", after)
print("Rows changed:", after - before)
# Out:
# Customers + Transaction Features
# Before: 5000
# After : 5000
# Rows changed: 0

# %% [markdown]
# # 9. Merge interaction features

# %%
before = len(final_df)

final_df = final_df.merge(
    interaction_features,
    on="customer_id",
    how="left",
    validate="one_to_one"
)

after = len(final_df)

print("\n+ Interaction Features")
print("Before:", before)
print("After :", after)
print("Rows changed:", after - before)
# Out:
# + Interaction Features
# Before: 5000
# After : 5000
# Rows changed: 0

# %% [markdown]
# # 10. Merge support ticket features

# %%
before = len(final_df)

final_df = final_df.merge(
    ticket_features,
    on="customer_id",
    how="left",
    validate="one_to_one"
)

after = len(final_df)

print("\n+ Support Ticket Features")
print("Before:", before)
print("After :", after)
print("Rows changed:", after - before)
# Out:
# + Support Ticket Features
# Before: 5000
# After : 5000
# Rows changed: 0

# %% [markdown]
# # 11. Merge review features

# %%
before = len(final_df)

final_df = final_df.merge(
    review_features,
    on="customer_id",
    how="left",
    validate="one_to_one"
)

after = len(final_df)

print("\n+ Review Features")
print("Before:", before)
print("After :", after)
print("Rows changed:", after - before)
# Out:
# + Review Features
# Before: 5000
# After : 5000
# Rows changed: 0

# %% [markdown]
# # 12. Validate the final merged dataset

# %%
print("\n" + "=" * 60)
print("FINAL MERGED DATASET VALIDATION")
print("=" * 60)

print("Initial customer rows:", initial_rows)
print("Final dataset rows   :", len(final_df))
print(
    "Unique customers     :",
    final_df["customer_id"].nunique()
)
print(
    "Duplicate customer IDs:",
    final_df["customer_id"].duplicated().sum()
)

if len(final_df) == initial_rows:
    print("\n✓ Row count preserved successfully.")
else:
    print("\n⚠ Row count changed. Investigate the merge relationships.")
# Out:
# ...
# FINAL MERGED DATASET VALIDATION
# ...
# Initial customer rows: 5000
# Final dataset rows   : 5000
# Unique customers     : 5000
# Duplicate customer IDs: 0
#
# ✓ Row count preserved successfully.

# %% [markdown]
# # 13. Display the final dataset structure

# %%
print("\nFinal dataset shape:", final_df.shape)

print("\nFinal dataset columns:")
print(final_df.columns.tolist())
# Out:
# Final dataset shape: (5000, 28)
#
# Final dataset columns:
# ['customer_id', 'full_name', 'age', 'gender', 'email', 'phone', 'street_address', 'city', 'state', 'zip_code', 'registration_date', 'preferred_channel', 'total_transactions', 'total_quantity', 'total_spend', 'average_transaction_value', 'average_quantity', 'average_discount', 'unique_products', 'unique_categories', 'last_transaction_date', 'first_transaction_date', 'recency_days', 'customer_lifetime_days', 'total_interactions', 'total_tickets', 'total_reviews', 'average_rating']

# %% [markdown]
# # 14. Check missing values created by LEFT JOINs

# %%
print("\nMissing values in engineered features:")

print(
    final_df[
        [
            "total_transactions",
            "total_spend",
            "total_interactions",
            "total_tickets",
            "total_reviews",
            "average_rating"
        ]
    ].isnull().sum()
)
# Out:
# Missing values in engineered features:
# total_transactions     624
# total_spend            624
# total_interactions       6
# total_tickets         2804
# total_reviews         4170
# average_rating        4170
# dtype: int64

# %% [markdown]
# # 15. Display first five rows

# %%
print("\nFirst 5 rows of final dataset:")

display(final_df.head())
# Out:
# First 5 rows of final dataset:
#                             customer_id       full_name   age  gender  \
# 0  4c30e132-0704-4459-a509-9eddde934977    Mark Johnson  40.0    Male
# 1  68bec407-275f-4b5b-9a82-13d02f54626a    Robert Smith  33.0    Male
# 2  4466459f-76c8-433c-814e-6d59cb4131fc    Jamie Chavez  42.0  Female
# 3  04c36a25-02f3-462c-92b0-6bf291c57706  Thomas Bradley  53.0    Male
# 4  e916df3d-c3f5-40b0-8ae2-5d043be88300    Jane Ferrell  32.0  Female
#
#                         email               phone  \
# 0      mark.johnson@yahoo.com        989.608.3863
# 1            smithr@yahoo.com  (518)349-5931x0341
# 2           jchavez@gmail.com    364.583.5030x564
# 3  thomas.bradley@hotmail.com   (332)887-1012x269
# 4    jane.ferrell@hotmail.com          5484281489
#
#                 street_address        city     state  zip_code  \
# 0           819 Johnson Course     Houston     Texas   29158.0
# 1  35116 Michael Key Suite 078      Austin     Texas   16862.0
# ...

# %% [markdown]
# # 6. Record the number of rows before and after every merge.

# %%
merge_log = []


def audited_merge(left, right, name):

    rows_before = len(left)

    result = left.merge(
        right,
        on="customer_id",
        how="left",
        validate="one_to_one"
    )

    rows_after = len(result)

    duplicate_customer_ids = result["customer_id"].duplicated().sum()

    merge_log.append({
        "Merge": name,
        "Rows Before": rows_before,
        "Right Rows": len(right),
        "Rows After": rows_after,
        "Duplicate Customer IDs": duplicate_customer_ids
    })

    return result

# %% [markdown]
# # 7. Investigate duplicated records created by joining.

# %%
def check_duplicates(df, name):

    duplicates = df[df["customer_id"].duplicated(keep=False)]

    print("=" * 70)
    print(name)
    print("Total rows:", len(df))
    print("Unique customers:", df["customer_id"].nunique())
    print("Duplicate customer records:", len(duplicates))

    if len(duplicates) > 0:
        display(duplicates.head(20))
    else:
        print("No duplicated customer records found.")


check_duplicates(customers, "Customers")
# Out:
# ...
# Customers
# Total rows: 5000
# Unique customers: 5000
# Duplicate customer records: 0
# No duplicated customer records found.

# %% [markdown]
# # 8. Investigate unmatched keys.

# %%
def check_unmatched(parent, child, name):

    parent_keys = set(parent["customer_id"].dropna())
    child_keys = set(child["customer_id"].dropna())

    matched = child_keys.intersection(parent_keys)
    unmatched = child_keys.difference(parent_keys)

    print("=" * 70)
    print(name)

    print("Child unique customer IDs:", len(child_keys))
    print("Matched customer IDs:", len(matched))
    print("Unmatched customer IDs:", len(unmatched))

    if unmatched:
        print("Unmatched IDs:")
        print(list(unmatched)[:20])
    else:
        print("No unmatched customer IDs found.")


check_unmatched(
    customers,
    transactions,
    "Transactions → Customers"
)

check_unmatched(
    customers,
    interactions,
    "Interactions → Customers"
)

check_unmatched(
    customers,
    support_tickets,
    "Support Tickets → Customers"
)

check_unmatched(
    customers,
    reviews,
    "Reviews → Customers"
)
# Out:
# ...
# Transactions → Customers
# Child unique customer IDs: 4618
# Matched customer IDs: 4618
# Unmatched customer IDs: 0
# No unmatched customer IDs found.
# ...
# Interactions → Customers
# Child unique customer IDs: 4994
# Matched customer IDs: 4994
# Unmatched customer IDs: 0
# No unmatched customer IDs found.
# ...
# Support Tickets → Customers
# Child unique customer IDs: 2196
# Matched customer IDs: 2196
# Unmatched customer IDs: 0
# No unmatched customer IDs found.
# ...
# Reviews → Customers
# Child unique customer IDs: 830
# Matched customer IDs: 830
# Unmatched customer IDs: 0
# No unmatched customer IDs found.

# %% [markdown]
# The foreign-key checks are used to determine whether every customer_id appearing in the child tables exists in customers.csv.
#
# For the supplied dataset, the customer-related tables use customer IDs that are represented in the customer master table.

# %% [markdown]
# # 9. Investigate missing values introduced during merging.

# %%
def missing_report(df, name):

    report = pd.DataFrame({
        "Missing Count": df.isnull().sum(),
        "Missing Percentage": (
            df.isnull().mean() * 100
        ).round(2)
    })

    report = report[
        report["Missing Count"] > 0
    ].sort_values(
        "Missing Count",
        ascending=False
    )

    print("=" * 70)
    print(name)

    display(report)


missing_report(
    customers,
    "Customers - Initial Missing Values"
)
# Out:
# ...
# Customers - Initial Missing Values
#                    Missing Count  Missing Percentage
# age                          186                3.72
# phone                        186                3.72
# street_address               177                3.54
# preferred_channel            114                2.28
# gender                       112                2.24
# email                        111                2.22
# full_name                    106                2.12
# city                          97                1.94
# zip_code                      96                1.92
# state                         93                1.86

# %% [markdown]
# # 10.Construct ONE final dataset for Machine Learning training.

# %%
# Convert date columns

customers["registration_date"] = pd.to_datetime(
    customers["registration_date"],
    errors="coerce"
)

transactions["transaction_date"] = pd.to_datetime(
    transactions["transaction_date"],
    errors="coerce"
)

interactions["interaction_date"] = pd.to_datetime(
    interactions["interaction_date"],
    errors="coerce"
)

support_tickets["submission_date"] = pd.to_datetime(
    support_tickets["submission_date"],
    errors="coerce"
)

support_tickets["resolution_date"] = pd.to_datetime(
    support_tickets["resolution_date"],
    errors="coerce"
)

reviews["review_date"] = pd.to_datetime(
    reviews["review_date"],
    errors="coerce"
)

# %% [markdown]
# Define the cutoff:

# %%
# Determine the prediction cutoff

reference_date = transactions["transaction_date"].max()

cutoff_date = (
    reference_date -
    pd.Timedelta(days=90)
)

print("Reference date:", reference_date)
print("Cutoff date:", cutoff_date)
# Out:
# Reference date: 2025-02-25 00:00:00
# Cutoff date: 2024-11-27 00:00:00

# %% [markdown]
# Create historical transactions:

# %%
historical_transactions = transactions[
    transactions["transaction_date"] <= cutoff_date
].copy()

# %% [markdown]
# Create transaction features:

# %%
transaction_features = (
    historical_transactions
    .groupby("customer_id")
    .agg(
        total_transactions=("transaction_id", "count"),
        total_quantity=("quantity", "sum"),
        total_spend=("price", "sum"),
        average_transaction_value=("price", "mean"),
        average_quantity=("quantity", "mean"),
        average_discount=("discount_applied", "mean"),
        unique_products=("product_name", "nunique"),
        unique_categories=("product_category", "nunique"),
        last_transaction_date=("transaction_date", "max"),
        first_transaction_date=("transaction_date", "min")
    )
    .reset_index()
)

transaction_features["recency_days"] = (
    cutoff_date -
    transaction_features["last_transaction_date"]
).dt.days

transaction_features["customer_lifetime_days"] = (
    transaction_features["last_transaction_date"] -
    transaction_features["first_transaction_date"]
).dt.days

# %% [markdown]
# # 11.Create an appropriate target variable.

# %% [markdown]
# Transactions occurring AFTER the cutoff are used only to determine whether the customer churned.

# %%
future_transactions = transactions[
    transactions["transaction_date"] > cutoff_date
].copy()

future_customer_ids = set(
    future_transactions["customer_id"]
)

customer_target = customers[
    ["customer_id"]
].copy()

customer_target["churn"] = (
    ~customer_target["customer_id"].isin(
        future_customer_ids
    )
).astype(int)

print("Churn distribution:")
display(
    customer_target["churn"].value_counts()
)

print("\nChurn percentage:")
display(
    customer_target["churn"].value_counts(
        normalize=True
    ) * 100
)
# Out:
# Churn distribution:
# churn
# 1    2585
# 0    2415
# Name: count, dtype: int64
# Churn percentage:
# churn
# 1    51.7
# 0    48.3
# Name: proportion, dtype: float64

# %% [markdown]
# # Target definition

# %% [markdown]
# churn = 1
# Customer made no purchase during the future 90-day period.
#
# churn = 0
# Customer made at least one purchase during the future 90-day period.

# %% [markdown]
# # 12.Perform feature engineering using information from multiple source tables.

# %% [markdown]
# # Interactions

# %%
historical_interactions = interactions[
    interactions["interaction_date"] <= cutoff_date
].copy()

interaction_features = (
    historical_interactions
    .groupby("customer_id")
    .agg(
        total_interactions=("interaction_id", "count"),
        unique_sessions=("session_id", "nunique"),
        average_interaction_duration=("duration", "mean"),
        unique_channels=("channel", "nunique"),
        unique_interaction_types=("interaction_type", "nunique")
    )
    .reset_index()
)

# %% [markdown]
# # Support tickets

# %%
historical_tickets = support_tickets[
    support_tickets["submission_date"] <= cutoff_date
].copy()

ticket_features = (
    historical_tickets
    .groupby("customer_id")
    .agg(
        total_tickets=("ticket_id", "count"),
        average_resolution_time=("resolution_time_hours", "mean"),
        average_satisfaction=("customer_satisfaction_score", "mean"),
        unique_issue_categories=("issue_category", "nunique")
    )
    .reset_index()
)

# %% [markdown]
# # Reviews

# %%
historical_reviews = reviews[
    reviews["review_date"] <= cutoff_date
].copy()

review_features = (
    historical_reviews
    .groupby("customer_id")
    .agg(
        total_reviews=("review_id", "count"),
        average_rating=("rating", "mean"),
        unique_reviewed_products=("product_name", "nunique"),
        unique_reviewed_categories=("product_category", "nunique")
    )
    .reset_index()
)

# %% [markdown]
# # Merge everything

# %%
# Start with customers

final_df = customers.copy()

# Merge transaction features
final_df = audited_merge(
    final_df,
    transaction_features,
    "Customers + Transaction Features"
)

# Merge interaction features
final_df = audited_merge(
    final_df,
    interaction_features,
    "Previous + Interaction Features"
)

# Merge support-ticket features
final_df = audited_merge(
    final_df,
    ticket_features,
    "Previous + Support Features"
)

# Merge review features
final_df = audited_merge(
    final_df,
    review_features,
    "Previous + Review Features"
)

# Merge target
final_df = audited_merge(
    final_df,
    customer_target,
    "Previous + Churn Target"
)

print("Final dataset shape:", final_df.shape)
# Out:
# Final dataset shape: (5000, 38)

# %% [markdown]
# # Display the merged audit:

# %%
# Displaying merge audit required by Questions 6 and 7

merge_audit_df = pd.DataFrame(merge_log)

display(merge_audit_df)
# Out:
#                               Merge  Rows Before  Right Rows  Rows After  \
# 0  Customers + Transaction Features         5000        4376        5000
# 1   Previous + Interaction Features         5000        4734        5000
# 2       Previous + Support Features         5000        1797        5000
# 3        Previous + Review Features         5000         704        5000
# 4           Previous + Churn Target         5000        5000        5000
#
#    Duplicate Customer IDs
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %% [markdown]
# # Check duplicates:

# %%
print(
    "Duplicate customer IDs:",
    final_df["customer_id"].duplicated().sum()
)

print(
    "Unique customers:",
    final_df["customer_id"].nunique()
)
# Out:
# Duplicate customer IDs: 0
# Unique customers: 5000

# %% [markdown]
# # Save the final dataset:

# %%
import os

# Create output directory
os.makedirs("data/processed", exist_ok=True)

# Define output path
final_dataset_path = "data/processed/final_ml_dataset.csv"

# Save final customer-level ML dataset
final_df.to_csv(
    final_dataset_path,
    index=False
)

print("Final ML dataset saved to:")
print(final_dataset_path)
# Out:
# Final ML dataset saved to:
# data/processed/final_ml_dataset.csv

# %% [markdown]
# # 13.Train at least four ML models.

# %% [markdown]
# # First prepare the dataset.

# %%
# Removing columns that should not be used directly by the model

drop_columns = [
    "customer_id",
    "full_name",
    "email",
    "phone",
    "street_address",
    "registration_date",
    "last_transaction_date",
    "first_transaction_date"
]

model_df = final_df.drop(
    columns=[
        col for col in drop_columns
        if col in final_df.columns
    ]
)

X = model_df.drop(
    columns=["churn"]
)

y = model_df["churn"]

# %% [markdown]
# # Split:

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (4000, 29)
# Testing data: (1000, 29)

# %% [markdown]
# # Preprocessing:

# %%
from sklearn import set_config

set_config(display="diagram")

best_model = grid_search.best_estimator_
best_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(sparse_threshold=0,
#                                    transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'zip_code',
#                                                    'total_transactions',
#                                                    'total_quantity',
#                                                    'total_spend',
#                                                    'average_transaction_value',
#                                                    'average_quantity',
# ...

# %% [markdown]
# # Models:

# %%
# TRAIN FOUR ML MODELS

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import (
    RandomForestClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier
)

# Model 1: Logistic Regression

logistic_model = Pipeline([
    ("preprocessor", preprocessor),
    (
        "model",
        LogisticRegression(
            max_iter=1000,
            random_state=42
        )
    )
])

# Model 2: Random Forest

random_forest_model = Pipeline([
    ("preprocessor", preprocessor),
    (
        "model",
        RandomForestClassifier(
            n_estimators=200,
            random_state=42
        )
    )
])

# Model 3: Gradient Boosting

gradient_boosting_model = Pipeline([
    ("preprocessor", preprocessor),
    (
        "model",
        GradientBoostingClassifier(
            random_state=42
        )
    )
])

# Model 4: Hist Gradient Boosting

hist_gradient_model = Pipeline([
    ("preprocessor", preprocessor),
    (
        "model",
        HistGradientBoostingClassifier(
            random_state=42
        )
    )
])

# Store all models

models = {
    "Logistic Regression": logistic_model,
    "Random Forest": random_forest_model,
    "Gradient Boosting": gradient_boosting_model,
    "Hist Gradient Boosting": hist_gradient_model
}

# Train all four models

for name, model in models.items():

    print(f"\nTraining: {name}")

    model.fit(
        X_train,
        y_train
    )

    print(f"{name} trained successfully.")

print("\nAll four models trained successfully.")
# Out:
# Training: Logistic Regression
# Logistic Regression trained successfully.
#
# Training: Random Forest
# Random Forest trained successfully.
#
# Training: Gradient Boosting
# Gradient Boosting trained successfully.
#
# Training: Hist Gradient Boosting
# Hist Gradient Boosting trained successfully.
#
# All four models trained successfully.

# %% [markdown]
# # Train:

# %%
models = {
    "Logistic Regression": logistic_model,
    "Random Forest": random_forest_model,
    "Gradient Boosting": gradient_boosting_model,
    "Hist Gradient Boosting": hist_gradient_model
}

for name, model in models.items():

    print("Training:", name)

    model.fit(
        X_train,
        y_train
    )

print("All four models trained successfully.")
# Out:
# Training: Logistic Regression
# Training: Random Forest
# Training: Gradient Boosting
# Training: Hist Gradient Boosting
# All four models trained successfully.

# %% [markdown]
# # 14.Perform feature selection.

# %%
# QUESTION 14: Perform feature selection

from sklearn.feature_selection import (
    SelectKBest,
    mutual_info_classif
)

feature_selection = SelectKBest(
    score_func=mutual_info_classif,
    k="all"
)

print(
    "Feature-selection method:",
    "Mutual Information"
)
# Out:
# Feature-selection method: Mutual Information

# %% [markdown]
# # Q15. Cross-validation and hyperparameter tuning

# %%
# QUESTION 15: Cross-validation and hyperparameter tuning

from sklearn.model_selection import (
    StratifiedKFold,
    GridSearchCV
)

cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

tuning_pipeline = Pipeline([
    ("preprocessor", preprocessor),

    (
        "feature_selection",
        SelectKBest(
            score_func=mutual_info_classif,
            k="all"
        )
    ),

    (
        "model",
        RandomForestClassifier(
            random_state=42
        )
    )
])

param_grid = {
    "feature_selection__k": [
        "all"
    ],

    "model__n_estimators": [
        100,
        200
    ],

    "model__max_depth": [
        None,
        10,
        20
    ],

    "model__min_samples_split": [
        2,
        5
    ]
}

grid_search = GridSearchCV(
    estimator=tuning_pipeline,
    param_grid=param_grid,
    cv=cv,
    scoring="roc_auc",
    n_jobs=-1,
    verbose=1
)

grid_search.fit(
    X_train,
    y_train
)

print("Best parameters:")
print(grid_search.best_params_)

print("\nBest cross-validation ROC-AUC:")
print(grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best parameters:
# {'feature_selection__k': 'all', 'model__max_depth': 20, 'model__min_samples_split': 5, 'model__n_estimators': 200}
#
# Best cross-validation ROC-AUC:
# 0.6078207610308326

# %% [markdown]
# The final model is:

# %%
from sklearn import set_config

set_config(display="diagram")

best_model = grid_search.best_estimator_
best_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(sparse_threshold=0,
#                                    transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'zip_code',
#                                                    'total_transactions',
#                                                    'total_quantity',
#                                                    'total_spend',
#                                                    'average_transaction_value',
#                                                    'average_quantity',
# ...

# %% [markdown]
# # Q16. Evaluate the final model

# %%
# Evaluating the final model

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

# Predictions
y_pred = best_model.predict(X_test)

# Probabilities
y_prob = best_model.predict_proba(X_test)[:, 1]

# Metrics
accuracy = accuracy_score(
    y_test,
    y_pred
)

precision = precision_score(
    y_test,
    y_pred
)

recall = recall_score(
    y_test,
    y_pred
)

f1 = f1_score(
    y_test,
    y_pred
)

roc_auc = roc_auc_score(
    y_test,
    y_prob
)

print("FINAL MODEL PERFORMANCE")
print("=" * 60)

print("Accuracy :", round(accuracy, 4))
print("Precision:", round(precision, 4))
print("Recall   :", round(recall, 4))
print("F1 Score :", round(f1, 4))
print("ROC-AUC  :", round(roc_auc, 4))

print("\nClassification Report:")
print(
    classification_report(
        y_test,
        y_pred
    )
)
# Out:
# FINAL MODEL PERFORMANCE
# ...
# Accuracy : 0.561
# Precision: 0.5704
# Recall   : 0.6112
# F1 Score : 0.5901
# ROC-AUC  : 0.5975
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.51      0.53       483
#            1       0.57      0.61      0.59       517
#
#     accuracy                           0.56      1000
#    macro avg       0.56      0.56      0.56      1000
# weighted avg       0.56      0.56      0.56      1000

# %% [markdown]
# # Confusion matrix:

# %%
cm = confusion_matrix(
    y_test,
    y_pred
)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm
)

disp.plot()

plt.title(
    "Confusion Matrix - Final Churn Model"
)

plt.show()

# %% [markdown]
# # Q17. Perform error analysis

# %%
# Performing error analysis

error_analysis = X_test.copy()

error_analysis["actual"] = y_test.values
error_analysis["predicted"] = y_pred
error_analysis["churn_probability"] = y_prob

error_analysis["error_type"] = np.select(
    [
        (
            (error_analysis["actual"] == 1) &
            (error_analysis["predicted"] == 0)
        ),

        (
            (error_analysis["actual"] == 0) &
            (error_analysis["predicted"] == 1)
        )
    ],

    [
        "False Negative",
        "False Positive"
    ],

    default="Correct"
)

print("Prediction error summary:")

display(
    error_analysis[
        "error_type"
    ].value_counts()
)
# Out:
# Prediction error summary:
# error_type
# Correct           561
# False Positive    238
# False Negative    201
# Name: count, dtype: int64

# %% [markdown]
# # View incorrect predictions:

# %%
incorrect_predictions = error_analysis[
    error_analysis["error_type"] != "Correct"
]

print(
    "Total incorrect predictions:",
    len(incorrect_predictions)
)

display(
    incorrect_predictions.head(20)
)
# Out:
# Total incorrect predictions: 439
#        age  gender            city          state  zip_code preferred_channel  \
# 4161  40.0    Male          Tucson        Arizona   24721.0            online
# 1332  32.0    Male        Savannah        Georgia   53046.0            online
# 4751   NaN  Female    Philadelphia   Pennsylvania   57892.0              both
# 4463  48.0  Female        San Jose     California   66519.0            online
# 2784  29.0  Female           Tampa        Florida   21359.0              both
# 2428  48.0  Female      Fort Worth          Texas   60046.0              both
# 2956  46.0  Female           Miami        Florida   59671.0              both
# 223   18.0    Male      Pittsburgh   Pennsylvania   76491.0            online
# 4786  43.0  Female           Tampa        Florida   58128.0            online
# 2048  31.0  Female     Jersey City     New Jersey   10842.0            online
# 2943  32.0    Male   San Francisco     California   25897.0            online
# ...

# %% [markdown]
# # Q18. Document complete data lineage Code

# %%
# Documenting the complete data lineage=

data_lineage = """
RAW DATA
│
├── customers.csv
│       │
│       └── Customer demographic information
│
├── transactions.csv
│       │
│       └── Historical transaction aggregation
│
├── interactions.csv
│       │
│       └── Historical interaction aggregation
│
├── support_tickets.csv
│       │
│       └── Historical support aggregation
│
├── customer_reviews_complete.csv
│       │
│       └── Historical review aggregation
│
└── campaigns.csv
        │
        └── No direct customer_id relationship
        │
        ▼
CUSTOMER-LEVEL FEATURE TABLE
        │
        ▼
TARGET CREATION
        │
        ▼
FINAL ML DATASET
        │
        ▼
PREPROCESSING
        │
        ▼
FEATURE SELECTION
        │
        ▼
MODEL TRAINING
        │
        ▼
HYPERPARAMETER TUNING
        │
        ▼
FINAL MODEL
        │
        ▼
DEPLOYMENT
"""

print(data_lineage)
# Out:
# RAW DATA
# │
# ├── customers.csv
# │       │
# │       └── Customer demographic information
# │
# ├── transactions.csv
# │       │
# │       └── Historical transaction aggregation
# │
# ├── interactions.csv
# │       │
# │       └── Historical interaction aggregation
# │
# ├── support_tickets.csv
# │       │
# │       └── Historical support aggregation
# │
# ├── customer_reviews_complete.csv
# │       │
# │       └── Historical review aggregation
# │
# └── campaigns.csv
#         │
#         └── No direct customer_id relationship
#         │
#         ▼
# CUSTOMER-LEVEL FEATURE TABLE
#         │
#         ▼
# TARGET CREATION
#         │
#         ▼
# FINAL ML DATASET
#         │
#         ▼
# PREPROCESSING
#         │
#         ▼
# FEATURE SELECTION
#         │
#         ▼
# MODEL TRAINING
#         │
#         ▼
# HYPERPARAMETER TUNING
#         │
#         ▼
# FINAL MODEL
#         │
#         ▼
# DEPLOYMENT

# %% [markdown]
# # Q19. Deploy the final model

# %%
# Final Model Deployment: Save the best model to disk for future use

import joblib
import os

model_directory = "/mnt/data/AssignmentFour_processed/models"

os.makedirs(
    model_directory,
    exist_ok=True
)

model_path = os.path.join(
    model_directory,
    "final_churn_model.joblib"
)

joblib.dump(
    best_model,
    model_path
)

print("Final model saved successfully.")
print(model_path)
# Out:
# Final model saved successfully.
# /mnt/data/AssignmentFour_processed/models\final_churn_model.joblib

# %% [markdown]
# # Verify:

# %%
# Load the saved model to verify that it works

loaded_model = joblib.load(
    model_path
)

print(
    "Saved model loaded successfully."
)

print(
    "Model type:",
    type(loaded_model)
)
# Out:
# Saved model loaded successfully.
# Model type: <class 'sklearn.pipeline.Pipeline'>

# %% [markdown]
# # Four models comparison using Accuracy, Precision, Recall and F1-score

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd
import matplotlib.pyplot as plt

results = []

for name, model in models.items():
    
    y_pred = model.predict(X_test)
    
    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, average="weighted"),
        "Recall": recall_score(y_test, y_pred, average="weighted"),
        "F1 Score": f1_score(y_test, y_pred, average="weighted")
    })

results_df = pd.DataFrame(results)

print(results_df)
# Out:
#                     Model  Accuracy  Precision  Recall  F1 Score
# 0     Logistic Regression     0.507   0.505461   0.507  0.505111
# 1           Random Forest     0.563   0.562237   0.563  0.561846
# 2       Gradient Boosting     0.556   0.556061   0.556  0.556028
# 3  Hist Gradient Boosting     0.544   0.544063   0.544  0.544029

# %% [markdown]
# # Models Visualization:

# %%
results_df.set_index("Model").plot(
    kind="bar",
    figsize=(12, 6)
)

plt.title("Performance Comparison of Machine Learning Models")
plt.xlabel("Machine Learning Model")
plt.ylabel("Score")
plt.ylim(0, 1)
plt.xticks(rotation=0)
plt.legend(title="Metrics")
plt.grid(axis="y", alpha=0.3)

plt.show()

# %% [markdown]
# # Visualize the confusion matrix for each model

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

for name, model in models.items():
    
    y_pred = model.predict(X_test)
    
    ConfusionMatrixDisplay.from_predictions(
        y_test,
        y_pred
    )
    
    plt.title(f"Confusion Matrix - {name}")
    plt.show()

# %% [markdown]
# # ROC-AUC Comparison

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))

for name, model in models.items():
    
    y_probability = model.predict_proba(X_test)[:, 1]
    
    fpr, tpr, _ = roc_curve(y_test, y_probability)
    roc_auc = auc(fpr, tpr)
    
    plt.plot(
        fpr,
        tpr,
        label=f"{name} (AUC = {roc_auc:.3f})"
    )

plt.plot([0, 1], [0, 1], linestyle="--")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison of Four Models")
plt.legend()
plt.grid(alpha=0.3)

plt.show()
